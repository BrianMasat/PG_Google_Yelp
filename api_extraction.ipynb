# %%
import pandas as pd
import ast
import requests

# %%
rows = []

with open('archivos2\checkin.json') as f:
    for line in f.readlines():
        rows.append(ast.literal_eval(line))

df = pd.DataFrame(rows)

# %%
df
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# ...

# %%
import requests

url = "https://travel-co2-climate-carbon-emissions.p.rapidapi.com/api/v1/simpletrips"

payload = {
	"from": "Berlin, Germany",
	"to": "Stockholm, Sweden",
	"ways": 2,
	"people": 2,
	"language": "en",
	"title": "Comparing flying and public transport from Berlin to Stockholm.",
	"transport_types": ["flying", "public-transport"]
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "ffdb25c0ffmsh30ff3b2a81d9ddap17e6dfjsnd40c0837375d",
	"X-RapidAPI-Host": "travel-co2-climate-carbon-emissions.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'title': 'Comparing flying and public transport from Berlin to Stockholm.', 'language': 'en', 'trips': [{'co2e': 430.6, 'steps': [{'discovery': True, 'location': {'placename': 'Tegel Airport, Germany', 'latitude': 52.5539, 'longitude': 13.2917, 'country': 'Germany', 'country_code': 'de', 'airport_iata': 'TXL'}, 'transport': {'ways': 2, 'people': 2, 'distance': 809406.8845815277, 'co2e_pp': 215.3, 'co2e': 430.6, 'vehicle': {'vehicle_count': 1, 'type': 'flight-regular-economy', 'title': 'Flight Regular Economy', 'fuel': None, 'consumption': None}, 'type': 'flying', 'title': 'Flying'}, 'accommodation': None}, {'discovery': True, 'location': {'placename': 'Bromma Airport, Sweden', 'latitude': 59.3557, 'longitude': 17.9461, 'country': 'Sweden', 'country_code': 'se', 'airport_iata': 'BMA'}, 'transport': None, 'accommodation': None}], 'language': 'en'}, {'co2e': 135.46, 'steps': [{'discovery': True, 'location': {'placename': 'Berlin, Germany', 'latitude': 52.5250839, 'longitude': 13.369402
# ...

# %%
response_json = response.json()

# %%
response.json()
# Out:
# {'title': 'Comparing flying and public transport from Berlin to Stockholm.',
#  'language': 'en',
#  'trips': [{'co2e': 430.6,
#    'steps': [{'discovery': True,
#      'location': {'placename': 'Tegel Airport, Germany',
#       'latitude': 52.5539,
#       'longitude': 13.2917,
#       'country': 'Germany',
#       'country_code': 'de',
#       'airport_iata': 'TXL'},
#      'transport': {'ways': 2,
#       'people': 2,
#       'distance': 809406.8845815277,
#       'co2e_pp': 215.3,
#       'co2e': 430.6,
#       'vehicle': {'vehicle_count': 1,
#        'type': 'flight-regular-economy',
#        'title': 'Flight Regular Economy',
#        'fuel': None,
#        'consumption': None},
#       'type': 'flying',
#       'title': 'Flying'},
#      'accommodation': None},
#     {'discovery': True,
#      'location': {'placename': 'Bromma Airport, Sweden',
#       'latitude': 59.3557,
#       'longitude': 17.9461,
#       'country': 'Sweden',
#       'country_code': 'se',
# ...

# %%
df = pd.DataFrame(response_json)

# %%
print(df)
# Out:
#                                                title language  \
# 0  Comparing flying and public transport from Ber...       en
# 1  Comparing flying and public transport from Ber...       en
#
#                                                trips
# 0  {'co2e': 430.6, 'steps': [{'discovery': True, ...
# 1  {'co2e': 135.46, 'steps': [{'discovery': True,...

# %%
import requests

url = "https://travel-co2-climate-carbon-emissions.p.rapidapi.com/api/v1/accommodation"

payload = {
	"type": "hotel",
	"nights": 3,
	"people": 1,
	"country_code": "us"
}
headers = {
	"content-type": "application/json",
	"Accept": "application/json",
	"Content-Type": "application/json",
	"Authorization": "Bearer {YOUR_API_KEY}",
	"X-RapidAPI-Key": "ffdb25c0ffmsh30ff3b2a81d9ddap17e6dfjsnd40c0837375d",
	"X-RapidAPI-Host": "travel-co2-climate-carbon-emissions.p.rapidapi.com"
}

response1 = requests.post(url, json=payload, headers=headers)

print(response1.json())
# Out:
# {'type': 'hotel', 'nights': 3, 'people': 1, 'country_code': 'us', 'co2e_pp': 39, 'co2e': 39, 'title': 'Hotel'}
